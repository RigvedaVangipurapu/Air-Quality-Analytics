# %%
pip install python-aqi
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/rigvedavangipurapu/Documents/AirQualityProject/myenv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import aqi

# %%
a1 = aqi.to_iaqi(aqi.POLLUTANT_PM25, '12', algo=aqi.ALGO_EPA)
a2 = aqi.to_iaqi(aqi.POLLUTANT_PM10, '10', algo=aqi.ALGO_EPA)
a3 = aqi.to_iaqi(aqi.POLLUTANT_O3_8H, '0.087', algo=aqi.ALGO_EPA)
print((a1+a2+a3)/3)
# Out:
# 62.66666666666666666666666667

# %%
myaqi = aqi.to_aqi([
    (aqi.POLLUTANT_PM25, '12'),
    (aqi.POLLUTANT_PM10, '24'),
    (aqi.POLLUTANT_O3_8H, '0.087')
])
myaqi
# Out:
# Decimal('129')
